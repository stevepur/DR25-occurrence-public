# %%
import numpy as np
import requests
import pandas as pd
from cStringIO import StringIO
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

# %%
# DR25 no cuts
catalogHeader = "dr25_stellar_updated_feh_all"
DR25Supp = pd.read_csv("../stellarCatalogs/" + catalogHeader + ".txt")
print("the DR25 catalog has " + str(len(DR25Supp)) + " entries")
# Out:
# the DR25 catalog has 200038 entries

# %% [markdown]
# Now bring in Hardegree-Ullman 2019

# %%
from astropy.io import ascii


huStellarSpectral = ascii.read("stellarCatalogs/Hardegree-Ullmann_spectral.txt")
huStellarPhoto = ascii.read("stellarCatalogs/Hardegree-Ullmann_photometric.txt")

huStellarSpectral = huStellarSpectral.to_pandas();
huStellarPhoto = huStellarPhoto.to_pandas();

dropCols = list(set(huStellarSpectral) - set(huStellarPhoto))
huStellarSpectral = huStellarSpectral.drop(columns = dropCols)
stellarProps = pd.concat([huStellarSpectral, huStellarPhoto], ignore_index=True)
stellarProps['KIC'] = stellarProps['KIC'].astype(int)

# %%
thisStar = stellarProps[stellarProps.KIC == 6444896]
thisStar
# Out:
#         KIC       D    e_D  KsMag  e_KsMag SpType  Teff     R*   e_R*     M*  \
# 76  6444896  92.191  0.546  7.764    0.029    M5V  3073  0.231  0.007  0.199
#
#      e_M*
# 76  0.005

# %%
list(DR25Supp)
# Out:
# ['kepid',
#  'tm_designation',
#  'teff',
#  'teff_err1',
#  'teff_err2',
#  'logg',
#  'logg_err1',
#  'logg_err2',
#  'feh',
#  'feh_err1',
#  'feh_err2',
#  'mass',
#  'mass_err1',
#  'mass_err2',
#  'radius',
#  'radius_err1',
#  'radius_err2',
#  'dens',
#  'dens_err1',
#  'dens_err2',
#  'prov_sec',
#  'kepmag',
#  'limbdark_coeff1',
#  'limbdark_coeff2',
#  'limbdark_coeff3',
#  'limbdark_coeff4',
#  'dist',
#  'dist_err1',
#  'dist_err2',
#  'nconfp',
#  'nkoi',
#  'ntce',
#  'datalink_dvr',
#  'st_delivname',
#  'st_vet_date_str',
#  'ra',
#  'dec',
#  'st_quarters',
#  'teff_prov',
#  'logg_prov',
#  'feh_prov',
#  'jmag',
#  'jmag_err',
#  'hmag',
#  'hmag_err',
#  'kmag',
#  'kmag_err',
#  'dutycycle',
#  'dataspan',
#  'mesthres01p5',
#  'mesthres02p0',
#  'mesthres02p5',
#  'mesthres03p0',
#  'mesthres03p5',
#  'mesthres04p5',
#  'mesthres05p0',
#  'mesthres06p0',
#  'mesthres07p5',
#  'mesthres09p0',
#  'mesthres10p5',
#  'mesthres12p0',
#  'mesthres12p5',
#  'mesthres15p0',
#  'rrmscdpp01p5',
#  'rrmscdpp02p0',
#  'rrmscdpp02p5',
#  'rrmscdpp03p0',
#  'rrmscdpp03p5',
#  'rrmscdpp04p5',
#  'rrmscdpp05p0',
#  'rrmscdpp06p0',
#  'rrmscdpp07p5',
#  'rrmscdpp09p0',
#  'rrmscdpp10p5',
#  'rrmscdpp12p0',
#  'rrmscdpp12p5',
#  'rrmscdpp15p0',
#  'av',
#  'av_err1',
#  'av_err2',
#  'dutycycle_post',
#  'dataspan_post',
#  'timeout01p5',
#  'timeout02p0',
#  'timeout02p5',
#  'timeout03p0',
#  'timeout03p5',
#  'timeout04p5',
#  'timeout05p0',
#  'timeout06p0',
#  'timeout07p5',
#  'timeout09p0',
#  'timeout10p5',
#  'timeout12p0',
#  'timeout12p5',
#  'timeout15p0',
#  'timeoutsumry',
#  'cdppslplong',
#  'cdppslpshrt']

# %%
list(stellarProps)
# Out:
# ['KIC',
#  'D',
#  'e_D',
#  'KsMag',
#  'e_KsMag',
#  'SpType',
#  'Teff',
#  'R*',
#  'e_R*',
#  'M*',
#  'e_M*']

# %%
dr25HuStellar = pd.merge(DR25Supp, stellarProps, left_on="kepid", right_on="KIC", how="inner")
print("the DR25/HU catalog has " + str(len(dr25HuStellar)) + " entries")
# DO NOT remove the highRUWE flags
# Out:
# the DR25/HU catalog has 547 entries

# %%
plt.figure(figsize=(10,10));
plt.semilogy(DR25Supp.teff, DR25Supp.radius, ".k", ms=3, alpha=0.5)
plt.semilogy(dr25HuStellar.Teff, dr25HuStellar["R*"], ".r", ms=9, alpha=0.5)
plt.semilogy(thisStar.Teff, thisStar["R*"], "*g", ms=9, alpha=1.0)
plt.xlim(9500, 2500)
plt.legend(("DR25 stars", "Hardegree-Ullman mid M-Dwarfs", "Kepler-1649"));
plt.ylabel("radius");
plt.xlabel("teff");

# %%
# copy the dr25 distance and radius to renamed columns in case anyone wants to compare
dr25HuStellar["teff_DR25"] = dr25HuStellar["teff"]
dr25HuStellar["teff_DR25_err1"] = dr25HuStellar["teff_err1"]
dr25HuStellar["teff_DR25_err2"] = dr25HuStellar["teff_err2"]

dr25HuStellar["logg_DR25"] = dr25HuStellar["logg"]
dr25HuStellar["logg_DR25_err1"] = dr25HuStellar["logg_err1"]
dr25HuStellar["logg_DR25_err2"] = dr25HuStellar["logg_err2"]

dr25HuStellar["mass_DR25"] = dr25HuStellar["mass"]
dr25HuStellar["mass_DR25_err1"] = dr25HuStellar["mass_err1"]
dr25HuStellar["mass_DR25_err2"] = dr25HuStellar["mass_err2"]

dr25HuStellar["mass_DR25"] = dr25HuStellar["mass"]
dr25HuStellar["mass_DR25_err1"] = dr25HuStellar["mass_err1"]
dr25HuStellar["mass_DR25_err2"] = dr25HuStellar["mass_err2"]

# copy isochrone data to the dr25 data columns

dr25HuStellar["teff"] = dr25HuStellar["Teff"]
dr25HuStellar["teff_err1"] = 0
dr25HuStellar["teff_err2"] = 0

dr25HuStellar["radius"] = dr25HuStellar["R*"]
dr25HuStellar["radius_err1"] = dr25HuStellar["e_R*"]
dr25HuStellar["radius_err2"] = -dr25HuStellar["e_R*"]

dr25HuStellar["mass"] = dr25HuStellar["M*"]
dr25HuStellar["mass_err1"] = dr25HuStellar["e_M*"]
dr25HuStellar["mass_err2"] = -dr25HuStellar["e_M*"]

# from mstar = 10.0**logg * rstar**2. / 10.0**4.437
solarLogg = 4.437
dr25HuStellar["logg"] = np.log10(dr25HuStellar["mass"]/(dr25HuStellar["radius"]**2)) + solarLogg
# should compute the following, except we never use it
dr25HuStellar["logg_err1"] = 0
dr25HuStellar["logg_err2"] = 0

# we'll leave the Gaia columns in place because they have different names
print("the dr25 HU catalog has " + str(len(dr25HuStellar)) + " entries")


dr25HuStellar.to_csv("stellarCatalogs/dr25_HU_stellar.txt", index=False)
thisStar = dr25HuStellar[dr25HuStellar.kepid == 6444896]
thisStar
# Out:
# the Berger2019 catalog has 547 entries
#        kepid           tm_designation  teff  teff_err1  teff_err2      logg  \
# 277  6444896  2MASS J19300092+4149496  3073          0          0  5.008629
#
#      logg_err1  logg_err2  feh  feh_err1       ...         e_M*  teff_DR25  \
# 277          0          0  0.0       0.0       ...        0.005       3073
#
#      teff_DR25_err1  teff_DR25_err2  logg_DR25  logg_DR25_err1  \
# 277               0               0   5.008629               0
#
#      logg_DR25_err2  mass_DR25  mass_DR25_err1  mass_DR25_err2
# 277               0      0.199           0.005          -0.005
#
# [1 rows x 119 columns]

# %%
# bring in Travis' catalog for comparison
travisStellar = pd.read_csv("../stellarCatalogs/GKSPC_InOut_V1.csv", dtype={"band":str})

# extract the integer kepid from the starname
iso_kepid = np.zeros((len(travisStellar),), dtype=np.int)
for i in range(len(travisStellar)):
    iso_kepid[i] = int(travisStellar["id_starname"][i][3:])

travisStellar["iso_kepid"] = iso_kepid
travisStellar = travisStellar.drop("id_starname", axis=1)

travisHuStellar = pd.merge(travisStellar, stellarProps, left_on="iso_kepid", right_on="KIC", how="inner")

# %%
plt.figure(figsize=(10,10));
plt.plot(travisStellar.iso_rad, travisStellar.iso_logg, ".k", ms=3, alpha=0.5)
plt.plot(dr25HuStellar.radius, dr25HuStellar.logg, ".r", ms=9, alpha=0.5)
plt.plot(thisStar.radius, thisStar.logg, "*g", ms=9, alpha=1.0)
plt.xlim(0,2)
plt.ylim(3,6)
plt.legend(("Berger2019 stars", "Hardegree-Ullman mid M-Dwarfs", "Kepler-1649"));
plt.ylabel("logg");
plt.xlabel("radius");

# %%
dr25HuStellar.logg
# Out:
# 0      4.853489
# 1      4.928720
# 2      4.910402
# 3      4.880960
# 4      5.137292
# 5      4.967869
# 6      4.843203
# 7      4.886890
# 8      4.848983
# 9      4.877996
# 10     4.613879
# 11     4.789615
# 12     4.804533
# 13     4.820985
# 14     4.979064
# 15     4.972128
# 16     4.987568
# 17     4.799508
# 18     4.876286
# 19     5.075392
# 20     4.999257
# 21     4.883375
# 22     4.845693
# 23     4.867053
# 24     4.720990
# 25     4.911089
# 26     4.861340
# 27     5.011165
# 28     5.064184
# 29     4.669844
#          ...
# 517    5.139350
# 518    5.176480
# 519    4.981061
# 520    5.187780
# 521    5.102030
# 522    5.193962
# 523    5.143490
# 524    5.117947
# 525    5.121901
# 526    5.133199
# 527    5.000216
# 528    4.862408
# 529    5.141416
# 530    4.884587
# 531    5.205716
# 532    5.003920
# 533    4.695061
# 534    4.903635
# 535    5.139350
# 536    4.736269
# 537    4.745019
# 538    4.903821
# 539    4.872831
# 540    4.804540
# 541    4.883245
# 542    4.965885
# 543    4.782821
# 544    4.829477
# 545    4.740637
# 546    4.738893
# Name: logg, Length: 547, dtype: float64

# %%
noisyTargets = pd.read_csv("../data/DR25_DEModel_NoisyTargetList.txt", header=9)
print("there are " + str(sum(midMDwarfDR25BergerStellar.kepid.isin(noisyTargets['# 1- Kepler ID']))) + " noisy targets")
print("this star " + str(sum(thisStarBergerFinal.kepid.isin(noisyTargets['# 1- Kepler ID']))) + " noisy targets")

# %%
m = np.isnan(midMDwarfDR25BergerStellar.limbdark_coeff1) \
    | np.isnan(midMDwarfDR25BergerStellar.limbdark_coeff2) \
    | np.isnan(midMDwarfDR25BergerStellar.limbdark_coeff3) \
    | np.isnan(midMDwarfDR25BergerStellar.limbdark_coeff4) 
print("there are " + str(sum(m)) + " nan limb darkening coeffs")

# %%
print("there are " + str(sum(np.isnan(midMDwarfDR25BergerStellar.dutycycle))) + " nan duty cycles")

# %%
dutyCycleChange = midMDwarfDR25BergerStellar.dutycycle - midMDwarfDR25BergerStellar.dutycycle_post
print("there are " + str(sum(dutyCycleChange/midMDwarfDR25BergerStellar.dutycycle > 0.3)) + " duty cycle change > 30%")
dutyCycleChange = thisStarBergerFinal.dutycycle - thisStarBergerFinal.dutycycle_post
print("this star " + str(sum(dutyCycleChange/thisStarBergerFinal.dutycycle > 0.3)) + " duty cycle change > 30%")

# %%
print("there are " + str(sum(midMDwarfDR25BergerStellar.dutycycle < 0.6)) + " duty cycle < 60%")
print("there are " + str(sum(midMDwarfDR25BergerStellar.dutycycle < 0.4)) + " duty cycle < 40%")
print("there are " + str(sum(midMDwarfDR25BergerStellar.dutycycle < 0.2)) + " duty cycle < 20%")
print("this star's duty cycle: " + str(thisStarBergerFinal.dutycycle.values[0]))

# %%
print("there are " + str(sum(midMDwarfDR25BergerStellar.dataspan < 80)) + " data span < 80 days")
print("there are " + str(sum(midMDwarfDR25BergerStellar.dataspan < 100)) + " data span < 100 days")
print("there are " + str(sum(midMDwarfDR25BergerStellar.dataspan < 500)) + " data span < 500 days")
print("there are " + str(sum(midMDwarfDR25BergerStellar.dataspan < 1000)) + " data span < 1000 days")
print("this star's data span: " + str(thisStarBergerFinal.dataspan.values[0]))

# %%
print("there are " + str(sum(midMDwarfDR25BergerStellar.timeoutsumry != 1)) + " timeoutsumry != 1")
print("this star's timeoutsumry: " + str(thisStarBergerFinal.timeoutsumry.values[0]))

# %%
print("there are " + str(sum(np.isnan(midMDwarfDR25BergerStellar.radius))) + " nan stellar radii")
print("this star's timeoutsumry: " + str(thisStarBergerFinal.timeoutsumry.values[0]))

# %%
thisStarBergerFinal

# %% [markdown]
# we'll go ahead and remove the noisy targets and nan stellar radii

# %%
midMDwarfDR25BergerStellarClean = midMDwarfDR25BergerStellar[~midMDwarfDR25BergerStellar.kepid.isin(noisyTargets['# 1- Kepler ID'])]
midMDwarfDR25BergerStellarClean = midMDwarfDR25BergerStellarClean[~np.isnan(midMDwarfDR25BergerStellarClean.radius)]
print(str(len(midMDwarfDR25BergerStellarClean)) + " entries after removing noisy and nan radius targets")

# %%
midMDwarfDR25BergerStellarClean.to_csv("stellarCatalogs/dr25_Berger2019_stellar_clean.txt", index=False)
